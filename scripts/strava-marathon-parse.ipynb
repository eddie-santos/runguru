# %%
import numpy as np
import pandas as pd
import re
import sys
import time

# %%
cities = ["2014-new-york-city","2015-boston","2014-san-francisco",
      "2014-chicago","2014-honolulu","2015-walt-disney-world","2015-los-angeles",
      "2015-san-diego-rock-n-roll","2014-twin-cities","2014-berlin","2014-dublin",
     "2015-big-sur","2015-london","2015-bay-of-mont-saint-michel","2014-savannah-rock-n-roll",
         "2014-auckland","2014-amsterdam"]
data = pd.DataFrame()
for i in xrange(len(cities)):
    print cities[i]
    f = open('/Users/Eddie/Dropbox/Insight/Project/raw_html/'+cities[i]+'.html','rU')
    activity = 0
    user = ""
    date = ""
    race = ""
    start_time = ""
    name = ""
    gender = ""
    age = 0
    time = 0
    pace = 0
    temp = pd.DataFrame()

    g = False
    for line in f:
        race_search = re.search(r'<h1>(\w.+)<',line)
        date_search = re.search(r'start-date\">(\w.+)<',line)
        start_search = re.search(r'start-time\">(\w.+)<',line)
        act_num = re.search(r'<tr data-activity_id=\"(\d+)\">',line)
        ath_id = re.search(r'<a class=\"avatar avatar-athlete\" href=\"\/athletes\/(\d+)\">',line) 
        ath_name = re.search(r'<img alt=\"(\w.+)\" src=',line)
        ath_gender = re.search(r'<td class=\"athlete-gender\">',line)
        ath_age = re.search(r'<td class=\"athlete-age\">(\d+)<\/td>',line)
        finish_time = re.search(r'<td class=\"finish-time\">(\d+):(\d+):(\d+)<\/td>',line)
        time_pace = re.search(r'<td class=\"finish-pace\">(\d+):(\d+)\/mi<\/td>',line)

        if date_search:
            date = date_search.group(1)
        if race_search:
            race = race_search.group(1)
        if start_search:
            start_time = start_search.group(1)
        if act_num:
            activity = int(act_num.group(1))
        if ath_id:
            user = ath_id.group(1)
        if ath_name:
            name = ath_name.group(1)
        if ath_gender:
            ath_gender2 = re.search(r'^(\w+)',next(f))
            if ath_gender2: gender = ath_gender2.group(1)
        if ath_age:
            age = int(ath_age.group(1))
        if finish_time:
            time = int(int(finish_time.group(1))*60*60 + int(finish_time.group(2))*60 + int(finish_time.group(3)))
        if time_pace:
            pace = int(60*int(time_pace.group(1)) + int(time_pace.group(2)))
            temp = temp.append([[name,date,start_time,race,gender,age,user,activity,time,pace]])
    f.close()
    temp.columns=['name','date','start_time','race','gender','age','user','activity','m_time','m_pace']
    temp = temp.drop_duplicates()
    data = data.append(temp)
# Out:
# 2014-new-york-city
# 2015-boston
# 2014-san-francisco
# 2014-chicago
# 2014-honolulu
# 2015-walt-disney-world
# 2015-los-angeles
# 2015-san-diego-rock-n-roll
# 2014-twin-cities
# 2014-berlin
# 2014-dublin
# 2015-big-sur
# 2015-london
# 2015-bay-of-mont-saint-michel
# 2014-savannah-rock-n-roll
# 2014-auckland
# 2014-amsterdam

# %%
goals = pd.DataFrame()
for i in xrange(len(cities)):
    g = open('/Users/Eddie/Dropbox/Insight/Project/raw_html/'+cities[i]+'.html','rU')
    temp = re.findall(r'\[(\d+),(\w+)\]',g.read())
    g.close()
    temp =  pd.DataFrame(temp).drop_duplicates()
    temp.columns = ['user','goal']
    goals = goals.append(temp)

# %%
combo = pd.merge(goals,data, how='inner',left_on = 'user', right_on = 'user')
combo = combo[combo['time']<36000]
combo = combo[combo['age']<100]
combo.to_csv("/Users/Eddie/Dropbox/Insight/Project/text_files/all_runners.csv",index=False)
all_data=combo[combo['goal']!='null']
all_data.to_csv("/Users/Eddie/Dropbox/Insight/Project/text_files/goal_runners.csv",index=False)

# %%
combo
# Out:
#           user   goal                   name              date start_time  \
# 0       869603   null            true indigo  November 2, 2014    7:30 AM
# 1      1651823   null       Florian Kimmel Ⓥ  November 2, 2014    7:30 AM
# 2      1585125   null      laurindo da costa  November 2, 2014    7:30 AM
# 3      2217441   null           Nicole Allen  November 2, 2014    7:30 AM
# 4      2357502   null             David Lock  November 2, 2014    7:30 AM
# 5      5111937   null             Brian Lane  November 2, 2014    7:30 AM
# 6      1226500   null    Christopher Malenab  November 2, 2014    7:30 AM
# 7      1226500   null    Christopher Malenab     July 27, 2014    5:30 AM
# 8      1226500   null    Christopher Malenab  November 2, 2014    7:30 AM
# 9      1226500   null    Christopher Malenab     July 27, 2014    5:30 AM
# 10     3643266   null       Paulette Ference  November 2, 2014    7:30 AM
# 11      770565   null         Jean Téménidès  November 2, 2014    7:30 AM
# 12     1143322   null            Karen Selby  November 2, 2014    7:30 AM
# 13      711862   null           massimo bava  November 2, 2014    7:30 AM
# 14     1020809   null       Brendan Trimboli  November 2, 2014    7:30 AM
# 15     5928488   null       Vincenzo Miliano  November 2, 2014    7:30 AM
# 16      294986   null            Henry Hoyle  November 2, 2014    7:30 AM
# 17       13989   null        Michael Shields  November 2, 2014    7:30 AM
# 18       13989   null        Michael Shields  November 2, 2014    7:30 AM
# 19     4819700   null             Luca Grisa  November 2, 2014    7:30 AM
# 20     1384703   null         chloe lasseron  November 2, 2014    7:30 AM
# 21     1384703   null         chloe lasseron    April 20, 2015   10:00 AM
# 22     1384703   null         chloe lasseron  November 2, 2014    7:30 AM
# 23     1384703   null         chloe lasseron    April 20, 2015   10:00 AM
# 24      741607   null            Eric Rayvid  November 2, 2014    7:30 AM
# 25      184563   null         Justin Frankel  November 2, 2014    7:30 AM
# 26     3632808   null             Jill Maxey  November 2, 2014    7:30 AM
# 27     3079047   null             Andrew Lee  November 2, 2014    7:30 AM
# 28      818343   null        Christian Ayala  November 2, 2014    7:30 AM
# 29     6066512   null       Jordan Rupprecht  November 2, 2014    7:30 AM
# ...        ...    ...                    ...               ...        ...
# 15638  1253088  14399            Rob Bergsma  October 19, 2014    9:30 AM
# 15639  3343391  14400         Roberta Camara  October 19, 2014    9:30 AM
# 16     New York City Marathon      M   42  214841063  13601   519
# 17     New York City Marathon      M   37  214887977  18384   701
# 18     New York City Marathon      M   37  214887977  18384   701
# 19     New York City Marathon      M   36  214905842  11586   442
# 20     New York City Marathon      F   30  215068433  15341   585
# 21            Boston Marathon      F   30  289402545  12011   458
# 22     New York City Marathon      F   30  215068433  15341   585
# 23            Boston Marathon      F   30  289402545  12011   458
# 24     New York City Marathon      M   45  214805312  15518   592
# 25     New York City Marathon      M   36  214824826  13639   520
# 26     New York City Marathon      F   37  215664646  18724   714
# 27     New York City Marathon      M   27  215009567  10661   407
# 28     New York City Marathon      M   35  214825665  17285   659
# 29     New York City Marathon      M   28  214910601  12450   475
# ...                       ...    ...  ...        ...    ...   ...
# 15638      Amsterdam Marathon      M   31  209296723  14316   546
# 15639      Amsterdam Marathon      F   42  212567645  14475   552
# 15640      Amsterdam Marathon      M   52  209184215  13870   529
# 15641      Amsterdam Marathon      F   34  209376925  14377   548
# 15642      Amsterdam Marathon      F   30  209563070  14518   554
# 15643      Amsterdam Marathon      M   36  209295620  16520   630
# 15644      Amsterdam Marathon      M   36  221230168  15737   600
# 15645      Amsterdam Marathon      M   45  210439203  16147   616
# 15646      Amsterdam Marathon      M   45  209706729  16445   627
# 15647      Amsterdam Marathon      M   33  209251677  18002   687
# 15648      Amsterdam Marathon      M   38  240305877  15940   608
# 15649      Amsterdam Marathon      F   46  209216571  16460   628
# 15650      Amsterdam Marathon      M   29  209518103  16866   643
# 15651      Amsterdam Marathon      M   41  209887282  18032   688
# 15652      Amsterdam Marathon      M   37  209183254  15863   605
# 15653      Amsterdam Marathon      M   37  209309452  15859   605
# 15654      Amsterdam Marathon      M   40  209358949  17477   667
# 15655      Amsterdam Marathon      M   35  209262370  14659   559
# 15656      Amsterdam Marathon      F   27  209174561  14854   567
# 15657      Amsterdam Marathon      M   32  209748395  16380   625
# 15658      Amsterdam Marathon      M   23  209780251  16012   611
# 15659      Amsterdam Marathon      M   35  209186749  18907   721
# 15660      Amsterdam Marathon      F   34  209157323  16101   614
# 15661      Amsterdam Marathon      M   36  209276216  18147   692
# 15662      Amsterdam Marathon      M   46  209343611  18381   701
# 15663      Amsterdam Marathon      F   38  209757899  16422   626
# 15664      Amsterdam Marathon      M   36  209286860  15748   601
# 15665      Amsterdam Marathon      M   50  210316320  17545   669
# 15666      Amsterdam Marathon      M   28  210141084  18898   721
# 15667      Amsterdam Marathon      F   29  209561804  20693   789
#
# [15618 rows x 11 columns]

# %%
con = mdb.connect('localhost', 'root', '', 'stravadb') 
cur = con.cursor()
cur.execute("DROP TABLE IF EXISTS stravadb")
sqlEngine = sqlalchemy.create_engine('mysql+pymysql://root@localhost/stravadb')
data.to_sql('stravadb', sqlEngine)
# data.to_csv('/Users/Eddie/Dropbox/Insight/data.csv')
